# %%
import pandas as pd

df = pd.ExcelFile('classes.xlsx') #insert file path
codebook_df = pd.read_excel(df, 'CodeBook')
codeBookDict = codebook_df.to_dict('records')[0]

#print(len(codeBookDict))
for code in list(codeBookDict):
    print(code, ":", codeBookDict[code], "\n")
# Out:
# n_very_unsatisfactory_course : Overall, this course was: Very Unsatisfactory
#
# pct_very_unsatisfactory_course : Overall, this course was: Very Unsatisfactory
#
# n_unsatisfactory_course : Overall, this course was: Unsatisfactory
#
# pct_unsatisfactory_course : Overall, this course was: Unsatisfactory
#
# n_satisfactory_course : Overall, this course was: Satisfactory
#
# pct_satisfactory_course : Overall, this course was: Satisfactory
#
# n_very_good_course : Overall, this course was: Very Good
#
# pct_very_good_course : Overall, this course was: Very Good
#
# n_excellent_course : Overall, this course was: Excellent
#
# pct_excellent_course : Overall, this course was: Excellent
#
# n_course_rating : [Number of respondents] Overall, this course was:
#
# avg_course_rating : [Average] Overall, this course was:
#
# dept_avg_course_rating : [Organization Average] Overall, this course was:
#
# college_avg_course_rating : [College/School Average] Overall, this course was:
#
# ...
